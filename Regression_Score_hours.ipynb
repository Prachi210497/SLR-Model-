# %% [markdown]
# <div align="center">
#     <h1>Test Score Prediction</h1>
#
#
#
# <img src="https://i.pinimg.com/736x/e6/ac/3b/e6ac3bb197bd1153b1c08b88660e0dfa.jpg" width="100%" alt="Test Score Prediction">
#
#
#
#
#
# Problem Statement: Prediction of the test Score based on the hours of study

# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Load Data File 

df = pd.read_csv("C:/Users/Win11/Documents/Industry_Projects/The_Spark_Foundation/Regression.csv")

# %%
# Top 5 

df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
# Number of Columns and rows 

df.shape
# Out:
# (25, 2)

# %%
# Data information 

df.info
# Out:
# <bound method DataFrame.info of     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86>

# %%
# Identification of Missing Values in the data

df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
# Descriptive Statistics of the Data

df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
df.value_counts().head(10)
# Out:
# Hours  Scores
# 1.1    17        1
# 5.1    47        1
# 8.9    95        1
# 8.5    75        1
# 8.3    81        1
# 7.8    86        1
# 7.7    85        1
# 7.4    69        1
# 6.9    76        1
# 6.1    67        1
# dtype: int64

# %%
# Linear Regression Plot 

plt.title('Regression Plot')
plt.scatter(x='Hours', y='Scores',s=10, c='r',marker='*',linewidth=3,data=df)
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %%
sns.regplot(x='Hours',y='Scores',label= 'Regplot',data=df)
# Out:
# <AxesSubplot:xlabel='Hours', ylabel='Scores'>

# %%
# Identification of Correlation 

df.corr()
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %%
# EDA using heatmap

sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
import statsmodels.api as sm
df = sm.add_constant(df['Hours'])
df.head(5)
# Out:
#    const  Hours
# 0    1.0    2.5
# 1    1.0    5.1
# 2    1.0    3.2
# 3    1.0    8.5
# 4    1.0    3.5

# %%
x= df.iloc[:, :-1].values  
y= df.iloc[:, 1].values

# %%
# training and testing of the data

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state =0 )

# %%
# Model building

from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(x_train,y_train)
slope = regressor.coef_
intercept = regressor.intercept_
print(intercept)
print(slope)
# Out:
# 5.24
# [0.]

# %%
df.head()
# Out:
#    const  Hours
# 0    1.0    2.5
# 1    1.0    5.1
# 2    1.0    3.2
# 3    1.0    8.5
# 4    1.0    3.5

# %%
# prediction of the score by studying 9.5 hours

Result = 5.24*9.5 + 1.0

# %%
print(Result)
# Out:
# 50.78

# %% [markdown]
# ## Insights & Recommendations
#
#
# Scatter Plot shows linear regression, Which indicates the more you study the better you can score. Also the Hours and Score features are highly correlated to each other.
# This model can be used in education centre to make student ensure the significance of time to score better.
